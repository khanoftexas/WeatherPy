# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from datetime import datetime

# Import API key
from config import (openweathermapy,gKey)
import gmaps

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "metric", "appid": openweathermapy}
summary = ["name","clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
cities_df = pd.DataFrame(["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"])
print("Beginning Data Retrieval")
print("-----------------------------")
counter = 0
weather_data = []
for city in cities:
    try:
        weather_data.append(ow.get_current(city, **settings))
        counter = counter +1
        print(f"Processing Record {counter} of {len(cities)} | {city}")
    except:
        print(f"City not found. Skipping... {city}")
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 607 | lompoc
# Processing Record 2 of 607 | punta arenas
# Processing Record 3 of 607 | altamont
# Processing Record 4 of 607 | la ronge
# Processing Record 5 of 607 | paamiut
# Processing Record 6 of 607 | kapaa
# Processing Record 7 of 607 | bluff
# Processing Record 8 of 607 | havre-saint-pierre
# Processing Record 9 of 607 | ushuaia
# Processing Record 10 of 607 | khatanga
# Processing Record 11 of 607 | waipawa
# Processing Record 12 of 607 | busselton
# Processing Record 13 of 607 | tuktoyaktuk
# Processing Record 14 of 607 | hithadhoo
# Processing Record 15 of 607 | agadez
# Processing Record 16 of 607 | jamestown
# Processing Record 17 of 607 | port alfred
# Processing Record 18 of 607 | chuy
# Processing Record 19 of 607 | jackson
# Processing Record 20 of 607 | puerto ayora
# City not found. Skipping... belushya guba
# Processing Record 21 of 607 | bredasdorp
# Processing Record 22 of 607 | taoudenni
# Processing Record 23 of 607 | portland
# Processing Record 24 of 607 | rikitea
# City not found. Skipping... el balyana
# Processing Record 25 of 607 | bondoukou
# Processing Record 26 of 607 | butaritari
# Processing Record 27 of 607 | san cristobal
# Processing Record 28 of 607 | hermanus
# Processing Record 29 of 607 | batemans bay
# Processing Record 30 of 607 | san carlos
# Processing Record 31 of 607 | cabo san lucas
# Processing Record 32 of 607 | severo-kurilsk
# Processing Record 33 of 607 | alta floresta
# Processing Record 34 of 607 | dikson
# Processing Record 35 of 607 | mataura
# City not found. Skipping... lalomanu
# Processing Record 36 of 607 | longyearbyen
# Processing Record 37 of 607 | hobart
# City not found. Skipping... vaitupu
# Processing Record 38 of 607 | new norfolk
# Processing Record 39 of 607 | albany
# Processing Record 40 of 607 | talnakh
# Processing Record 41 of 607 | pevek
# Processing Record 42 of 607 | vestmannaeyjar
# Processing Record 43 of 607 | batagay-alyta
# Processing Record 44 of 607 | esperance
# Processing Record 45 of 607 | kendari
# Processing Record 46 of 607 | hasaki
# Processing Record 47 of 607 | clyde river
# Processing Record 48 of 607 | qaanaaq
# City not found. Skipping... mys shmidta
# City not found. Skipping... uwayl
# Processing Record 49 of 607 | port hawkesbury
# Processing Record 50 of 607 | saint-philippe
# Processing Record 51 of 607 | tombouctou
# Processing Record 52 of 607 | cherskiy
# Processing Record 53 of 607 | barrow
# Processing Record 54 of 607 | cape town
# Processing Record 55 of 607 | yar-sale
# Processing Record 56 of 607 | georgetown
# City not found. Skipping... rungata
# Processing Record 57 of 607 | miri
# Processing Record 58 of 607 | gaoua
# City not found. Skipping... catamarca
# Processing Record 59 of 607 | qixia
# Processing Record 60 of 607 | lavrentiya
# Processing Record 61 of 607 | lorengau
# Processing Record 62 of 607 | tasiilaq
# Processing Record 63 of 607 | east london
# Processing Record 64 of 607 | nikolskoye
# Processing Record 65 of 607 | calafell
# Processing Record 66 of 607 | yining
# Processing Record 67 of 607 | kaitangata
# Processing Record 68 of 607 | port moresby
# Processing Record 69 of 607 | kudahuvadhoo
# Processing Record 70 of 607 | mar del plata
# Processing Record 71 of 607 | luderitz
# Processing Record 72 of 607 | vanavara
# City not found. Skipping... taolanaro
# Processing Record 73 of 607 | norman wells
# Processing Record 74 of 607 | harper
# Processing Record 75 of 607 | teshie
# City not found. Skipping... sentyabrskiy
# Processing Record 76 of 607 | amot
# Processing Record 77 of 607 | swan hill
# Processing Record 78 of 607 | bathsheba
# Processing Record 79 of 607 | vaini
# City not found. Skipping... bengkulu
# Processing Record 80 of 607 | bethel
# Processing Record 81 of 607 | avarua
# Processing Record 82 of 607 | yellowknife
# Processing Record 83 of 607 | torbay
# Processing Record 84 of 607 | bjorkelangen
# City not found. Skipping... barentsburg
# City not found. Skipping... odweyne
# City not found. Skipping... nizhneyansk
# Processing Record 85 of 607 | lagoa
# Processing Record 86 of 607 | santa marinella
# City not found. Skipping... illoqqortoormiut
# Processing Record 87 of 607 | nizhnevartovsk
# Processing Record 88 of 607 | ponta do sol
# Processing Record 89 of 607 | atuona
# Processing Record 90 of 607 | ilulissat
# Processing Record 91 of 607 | hilo
# Processing Record 92 of 607 | touros
# City not found. Skipping... attawapiskat
# Processing Record 93 of 607 | nemuro
# City not found. Skipping... stornoway
# Processing Record 94 of 607 | srednekolymsk
# Processing Record 95 of 607 | kysyl-syr
# City not found. Skipping... eldikan
# Processing Record 96 of 607 | mayo
# Processing Record 97 of 607 | sitka
# Processing Record 98 of 607 | mahebourg
# Processing Record 99 of 607 | zhezkazgan
# City not found. Skipping... tumannyy
# Processing Record 100 of 607 | westport
# City not found. Skipping... kismayo
# City not found. Skipping... amderma
# Processing Record 101 of 607 | belaya gora
# Processing Record 102 of 607 | salalah
# Processing Record 103 of 607 | karaton
# City not found. Skipping... palabuhanratu
# City not found. Skipping... taburi
# Processing Record 104 of 607 | riachao das neves
# Processing Record 105 of 607 | aras
# Processing Record 106 of 607 | kandry
# City not found. Skipping... artyk
# Processing Record 107 of 607 | tadine
# Processing Record 108 of 607 | arlit
# Processing Record 109 of 607 | camabatela
# Processing Record 110 of 607 | nortelandia
# Processing Record 111 of 607 | constitucion
# Processing Record 112 of 607 | zhuhai
# Processing Record 113 of 607 | oxchuc
# Processing Record 114 of 607 | carnarvon
# Processing Record 115 of 607 | kodiak
# Processing Record 116 of 607 | padang
# Processing Record 117 of 607 | obala
# Processing Record 118 of 607 | ust-maya
# Processing Record 119 of 607 | yenagoa
# City not found. Skipping... wulanhaote
# Processing Record 120 of 607 | shingu
# Processing Record 121 of 607 | laem sing
# Processing Record 122 of 607 | port elizabeth
# Processing Record 123 of 607 | kjollefjord
# Processing Record 124 of 607 | masvingo
# Processing Record 125 of 607 | narsaq
# Processing Record 126 of 607 | egvekinot
# City not found. Skipping... tsihombe
# Processing Record 127 of 607 | ancud
# Processing Record 128 of 607 | fortuna
# Processing Record 129 of 607 | lebu
# Processing Record 130 of 607 | bubaque
# City not found. Skipping... taraza
# Processing Record 131 of 607 | port-gentil
# Processing Record 132 of 607 | boa vista
# Processing Record 133 of 607 | saskylakh
# Processing Record 134 of 607 | sinnamary
# Processing Record 135 of 607 | namibe
# Processing Record 136 of 607 | kaniama
# Processing Record 137 of 607 | farafangana
# Processing Record 138 of 607 | thompson
# Processing Record 139 of 607 | campina verde
# Processing Record 140 of 607 | hare bay
# Processing Record 141 of 607 | arica
# Processing Record 142 of 607 | hay river
# City not found. Skipping... olafsvik
# Processing Record 143 of 607 | arraial do cabo
# Processing Record 144 of 607 | darhan
# Processing Record 145 of 607 | geraldton
# Processing Record 146 of 607 | north bend
# Processing Record 147 of 607 | mulege
# City not found. Skipping... lolua
# Processing Record 148 of 607 | camacha
# Processing Record 149 of 607 | atambua
# Processing Record 150 of 607 | kahului
# Processing Record 151 of 607 | lichinga
# Processing Record 152 of 607 | teeli
# Processing Record 153 of 607 | port lincoln
# Processing Record 154 of 607 | biak
# City not found. Skipping... ndele
# Processing Record 155 of 607 | poum
# Processing Record 156 of 607 | wonthaggi
# Processing Record 157 of 607 | castro
# Processing Record 158 of 607 | pisco
# Processing Record 159 of 607 | ekhabi
# Processing Record 160 of 607 | ribeira grande
# City not found. Skipping... samusu
# Processing Record 161 of 607 | goderich
# Processing Record 162 of 607 | lavras
# Processing Record 163 of 607 | san felipe
# Processing Record 164 of 607 | diffa
# Processing Record 165 of 607 | port hardy
# Processing Record 166 of 607 | nokaneng
# Processing Record 167 of 607 | baranchinskiy
# Processing Record 168 of 607 | chicama
# Processing Record 169 of 607 | chokurdakh
# Processing Record 170 of 607 | ruwi
# Processing Record 171 of 607 | ostrovnoy
# Processing Record 172 of 607 | zhigansk
# Processing Record 173 of 607 | iqaluit
# Processing Record 174 of 607 | alexandria
# Processing Record 175 of 607 | klaksvik
# Processing Record 176 of 607 | viedma
# Processing Record 177 of 607 | nagato
# Processing Record 178 of 607 | impfondo
# Processing Record 179 of 607 | sungairaya
# Processing Record 180 of 607 | katsuura
# Processing Record 181 of 607 | birnin kebbi
# Processing Record 182 of 607 | chara
# Processing Record 183 of 607 | laredo
# Processing Record 184 of 607 | jaora
# Processing Record 185 of 607 | kattivakkam
# City not found. Skipping... yunjinghong
# Processing Record 186 of 607 | lac du bonnet
# Processing Record 187 of 607 | boende
# City not found. Skipping... umzimvubu
# Processing Record 188 of 607 | tshikapa
# Processing Record 189 of 607 | san juan
# Processing Record 190 of 607 | upernavik
# Processing Record 191 of 607 | hobyo
# Processing Record 192 of 607 | avera
# Processing Record 193 of 607 | cayenne
# Processing Record 194 of 607 | sibolga
# Processing Record 195 of 607 | taltal
# Processing Record 196 of 607 | morehead
# Processing Record 197 of 607 | eyl
# Processing Record 198 of 607 | genhe
# City not found. Skipping... barawe
# Processing Record 199 of 607 | kaeo
# Processing Record 200 of 607 | port blair
# Processing Record 201 of 607 | ingham
# Processing Record 202 of 607 | jalu
# Processing Record 203 of 607 | aripuana
# Processing Record 204 of 607 | corinto
# Processing Record 205 of 607 | acapulco
# Processing Record 206 of 607 | saint george
# Processing Record 207 of 607 | richards bay
# Processing Record 208 of 607 | lyambir
# Processing Record 209 of 607 | cerro largo
# Processing Record 210 of 607 | victoria
# Processing Record 211 of 607 | sri aman
# Processing Record 212 of 607 | putina
# Processing Record 213 of 607 | veraval
# Processing Record 214 of 607 | puerto escondido
# Processing Record 215 of 607 | krasnoarmeysk
# Processing Record 216 of 607 | darnah
# Processing Record 217 of 607 | muskogee
# Processing Record 218 of 607 | victoriaville
# Processing Record 219 of 607 | loa janan
# Processing Record 220 of 607 | lokosovo
# Processing Record 221 of 607 | coolum beach
# Processing Record 222 of 607 | san isidro
# Processing Record 223 of 607 | nanortalik
# Processing Record 224 of 607 | tongzi
# Processing Record 225 of 607 | marystown
# Processing Record 226 of 607 | kavaratti
# Processing Record 227 of 607 | ironton
# City not found. Skipping... valjala
# Processing Record 228 of 607 | provideniya
# Processing Record 229 of 607 | bay roberts
# Processing Record 230 of 607 | sao francisco do sul
# Processing Record 231 of 607 | yongan
# Processing Record 232 of 607 | tibiri
# Processing Record 233 of 607 | xiaoweizhai
# Processing Record 234 of 607 | nome
# Processing Record 235 of 607 | nuqui
# Processing Record 236 of 607 | dingle
# Processing Record 237 of 607 | den helder
# Processing Record 238 of 607 | shimoda
# Processing Record 239 of 607 | pangnirtung
# Processing Record 240 of 607 | sur
# Processing Record 241 of 607 | ganj muradabad
# Processing Record 242 of 607 | didao
# Processing Record 243 of 607 | half moon bay
# Processing Record 244 of 607 | san antonio
# Processing Record 245 of 607 | loandjili
# Processing Record 246 of 607 | cosamaloapan
# Processing Record 247 of 607 | tura
# Processing Record 248 of 607 | kayerkan
# Processing Record 249 of 607 | lar
# City not found. Skipping... pemangkat
# Processing Record 250 of 607 | inhambane
# Processing Record 251 of 607 | northam
# City not found. Skipping... krasnoselkup
# Processing Record 252 of 607 | vigrestad
# Processing Record 253 of 607 | grand-lahou
# Processing Record 254 of 607 | visnes
# Processing Record 255 of 607 | panguna
# Processing Record 256 of 607 | uruzgan
# Processing Record 257 of 607 | rincon
# Processing Record 258 of 607 | parabel
# Processing Record 259 of 607 | tarauaca
# Processing Record 260 of 607 | muhos
# City not found. Skipping... temaraia
# City not found. Skipping... sakakah
# Processing Record 261 of 607 | ust-kulom
# Processing Record 262 of 607 | svecha
# Processing Record 263 of 607 | birin
# Processing Record 264 of 607 | mahibadhoo
# Processing Record 265 of 607 | catuday
# Processing Record 266 of 607 | kamenka
# Processing Record 267 of 607 | syamzha
# Processing Record 268 of 607 | bandarbeyla
# Processing Record 269 of 607 | sorong
# Processing Record 270 of 607 | norsup
# Processing Record 271 of 607 | sao jose da coroa grande
# City not found. Skipping... tatawin
# City not found. Skipping... maarianhamina
# Processing Record 272 of 607 | saint-georges
# Processing Record 273 of 607 | nakamura
# Processing Record 274 of 607 | henties bay
# Processing Record 275 of 607 | rocha
# Processing Record 276 of 607 | barauna
# Processing Record 277 of 607 | okahandja
# Processing Record 278 of 607 | anadyr
# Processing Record 279 of 607 | alekseyevsk
# Processing Record 280 of 607 | cidreira
# Processing Record 281 of 607 | thanh hoa
# Processing Record 282 of 607 | leningradskiy
# Processing Record 283 of 607 | burnie
# Processing Record 284 of 607 | sawakin
# City not found. Skipping... saleaula
# Processing Record 285 of 607 | york
# Processing Record 286 of 607 | valparaiso
# Processing Record 287 of 607 | rio grande
# Processing Record 288 of 607 | topolobampo
# Processing Record 289 of 607 | mapastepec
# Processing Record 290 of 607 | mount isa
# Processing Record 291 of 607 | vao
# Processing Record 292 of 607 | pacific grove
# Processing Record 293 of 607 | west wendover
# Processing Record 294 of 607 | prachuap khiri khan
# Processing Record 295 of 607 | karratha
# Processing Record 296 of 607 | verkhnevilyuysk
# City not found. Skipping... manguiring
# Processing Record 297 of 607 | brigantine
# Processing Record 298 of 607 | lensk
# Processing Record 299 of 607 | chinsali
# Processing Record 300 of 607 | ust-koksa
# Processing Record 301 of 607 | tautira
# Processing Record 302 of 607 | kutum
# Processing Record 303 of 607 | orbetello
# Processing Record 304 of 607 | san benito abad
# Processing Record 305 of 607 | campo formoso
# Processing Record 306 of 607 | atar
# Processing Record 307 of 607 | acajutla
# City not found. Skipping... inveraray
# Processing Record 308 of 607 | rawson
# Processing Record 309 of 607 | jining
# Processing Record 310 of 607 | san quintin
# Processing Record 311 of 607 | leh
# Processing Record 312 of 607 | porto novo
# Processing Record 313 of 607 | doha
# Processing Record 314 of 607 | boyolangu
# Processing Record 315 of 607 | baturaja
# Processing Record 316 of 607 | inverell
# Processing Record 317 of 607 | aksarka
# Processing Record 318 of 607 | atbasar
# Processing Record 319 of 607 | banyo
# Processing Record 320 of 607 | yulara
# Processing Record 321 of 607 | sao filipe
# Processing Record 322 of 607 | mehran
# Processing Record 323 of 607 | kieta
# Processing Record 324 of 607 | san policarpo
# Processing Record 325 of 607 | vardo
# Processing Record 326 of 607 | blind river
# Processing Record 327 of 607 | kushiro
# Processing Record 328 of 607 | esna
# Processing Record 329 of 607 | beloha
# Processing Record 330 of 607 | aksha
# Processing Record 331 of 607 | sorland
# City not found. Skipping... dolbeau
# Processing Record 332 of 607 | husavik
# Processing Record 333 of 607 | manzhouli
# City not found. Skipping... marang
# Processing Record 334 of 607 | manokwari
# Processing Record 335 of 607 | bud
# Processing Record 336 of 607 | kenai
# Processing Record 337 of 607 | mount gambier
# Processing Record 338 of 607 | ginir
# Processing Record 339 of 607 | gornyatskiy
# Processing Record 340 of 607 | yaan
# Processing Record 341 of 607 | kananga
# Processing Record 342 of 607 | codrington
# Processing Record 343 of 607 | phan thiet
# Processing Record 344 of 607 | haikou
# Processing Record 345 of 607 | byron bay
# Processing Record 346 of 607 | menongue
# Processing Record 347 of 607 | quatre cocos
# Processing Record 348 of 607 | olinda
# Processing Record 349 of 607 | jiazi
# Processing Record 350 of 607 | along
# Processing Record 351 of 607 | gladstone
# Processing Record 352 of 607 | nantucket
# Processing Record 353 of 607 | ventspils
# Processing Record 354 of 607 | zemetchino
# Processing Record 355 of 607 | fairbanks
# City not found. Skipping... hongan
# Processing Record 356 of 607 | sungaipenuh
# Processing Record 357 of 607 | mogadishu
# Processing Record 358 of 607 | hereford
# Processing Record 359 of 607 | rio gallegos
# Processing Record 360 of 607 | plonsk
# Processing Record 361 of 607 | pont-saint-esprit
# Processing Record 362 of 607 | san patricio
# Processing Record 363 of 607 | kollam
# Processing Record 364 of 607 | los llanos de aridane
# Processing Record 365 of 607 | key west
# Processing Record 366 of 607 | danilov
# Processing Record 367 of 607 | komsomolskiy
# Processing Record 368 of 607 | pocone
# Processing Record 369 of 607 | wicklow
# Processing Record 370 of 607 | tezu
# Processing Record 371 of 607 | auki
# Processing Record 372 of 607 | nichlaul
# Processing Record 373 of 607 | dolores
# Processing Record 374 of 607 | victor harbor
# Processing Record 375 of 607 | umm kaddadah
# Processing Record 376 of 607 | katangli
# Processing Record 377 of 607 | tiksi
# Processing Record 378 of 607 | saldanha
# Processing Record 379 of 607 | alofi
# Processing Record 380 of 607 | eldorado
# City not found. Skipping... tir pol
# City not found. Skipping... ust-kamchatsk
# Processing Record 381 of 607 | barcelos
# Processing Record 382 of 607 | galle
# Processing Record 383 of 607 | new haven
# Processing Record 384 of 607 | sambava
# Processing Record 385 of 607 | rexburg
# Processing Record 386 of 607 | gondar
# Processing Record 387 of 607 | guadalupe y calvo
# Processing Record 388 of 607 | kouango
# Processing Record 389 of 607 | goundam
# Processing Record 390 of 607 | saraland
# Processing Record 391 of 607 | sembakung
# Processing Record 392 of 607 | santa maria
# Processing Record 393 of 607 | tuatapere
# Processing Record 394 of 607 | lakatoro
# Processing Record 395 of 607 | vila velha
# Processing Record 396 of 607 | marawi
# Processing Record 397 of 607 | faanui
# Processing Record 398 of 607 | bilma
# Processing Record 399 of 607 | hibbing
# City not found. Skipping... sorvag
# Processing Record 400 of 607 | ramshir
# Processing Record 401 of 607 | perth
# Processing Record 402 of 607 | sfantu gheorghe
# Processing Record 403 of 607 | pavlodar
# City not found. Skipping... paradwip
# Processing Record 404 of 607 | samsun
# Processing Record 405 of 607 | chulumani
# Processing Record 406 of 607 | chowchilla
# Processing Record 407 of 607 | mana
# Processing Record 408 of 607 | sochaczew
# Processing Record 409 of 607 | san vicente
# Processing Record 410 of 607 | kyakhta
# Processing Record 411 of 607 | haimen
# City not found. Skipping... karkaralinsk
# Processing Record 412 of 607 | kavieng
# Processing Record 413 of 607 | alice springs
# Processing Record 414 of 607 | polson
# Processing Record 415 of 607 | tokur
# Processing Record 416 of 607 | guerrero negro
# City not found. Skipping... kamenskoye
# Processing Record 417 of 607 | sunnyside
# Processing Record 418 of 607 | sao joao da barra
# Processing Record 419 of 607 | caravelas
# Processing Record 420 of 607 | hervey bay
# Processing Record 421 of 607 | willowmore
# Processing Record 422 of 607 | oudtshoorn
# Processing Record 423 of 607 | orsta
# Processing Record 424 of 607 | taywarah
# Processing Record 425 of 607 | yuanping
# City not found. Skipping... bolshoy tsaryn
# Processing Record 426 of 607 | naze
# Processing Record 427 of 607 | savonlinna
# Processing Record 428 of 607 | turkmenabat
# City not found. Skipping... marcona
# Processing Record 429 of 607 | balabac
# Processing Record 430 of 607 | tommot
# City not found. Skipping... jiaojiang
# Processing Record 431 of 607 | acari
# City not found. Skipping... satitoa
# City not found. Skipping... berbera
# Processing Record 432 of 607 | poso
# Processing Record 433 of 607 | lazaro cardenas
# Processing Record 434 of 607 | ponta delgada
# Processing Record 435 of 607 | gushikawa
# Processing Record 436 of 607 | marsh harbour
# Processing Record 437 of 607 | gazojak
# Processing Record 438 of 607 | marsa matruh
# Processing Record 439 of 607 | adrar
# Processing Record 440 of 607 | knysna
# Processing Record 441 of 607 | indramayu
# Processing Record 442 of 607 | aizkraukle
# Processing Record 443 of 607 | watsa
# Processing Record 444 of 607 | qiongshan
# Processing Record 445 of 607 | lamar
# Processing Record 446 of 607 | ichhawar
# City not found. Skipping... korla
# City not found. Skipping... bolshaya chernigovka
# Processing Record 447 of 607 | hami
# Processing Record 448 of 607 | bintulu
# Processing Record 449 of 607 | sabha
# Processing Record 450 of 607 | araouane
# Processing Record 451 of 607 | calama
# Processing Record 452 of 607 | sola
# Processing Record 453 of 607 | kiunga
# Processing Record 454 of 607 | atasu
# Processing Record 455 of 607 | fare
# Processing Record 456 of 607 | isangel
# Processing Record 457 of 607 | pinheiro machado
# Processing Record 458 of 607 | akureyri
# City not found. Skipping... caninde
# Processing Record 459 of 607 | arawa
# Processing Record 460 of 607 | talaya
# Processing Record 461 of 607 | bambous virieux
# Processing Record 462 of 607 | kokoda
# Processing Record 463 of 607 | san borja
# Processing Record 464 of 607 | kirakira
# Processing Record 465 of 607 | tecalitlan
# Processing Record 466 of 607 | meybod
# Processing Record 467 of 607 | moron
# Processing Record 468 of 607 | bonneville
# Processing Record 469 of 607 | plainview
# Processing Record 470 of 607 | halifax
# Processing Record 471 of 607 | tikapur
# Processing Record 472 of 607 | weligama
# Processing Record 473 of 607 | aleksandrovsk
# Processing Record 474 of 607 | inuvik
# Processing Record 475 of 607 | zhob
# Processing Record 476 of 607 | peleduy
# Processing Record 477 of 607 | beringovskiy
# City not found. Skipping... samalaeulu
# Processing Record 478 of 607 | makat
# Processing Record 479 of 607 | khirkiya
# Processing Record 480 of 607 | severo-yeniseyskiy
# Processing Record 481 of 607 | santiago del estero
# Processing Record 482 of 607 | sovetsk
# Processing Record 483 of 607 | berlevag
# Processing Record 484 of 607 | fukagawa
# Processing Record 485 of 607 | xingyi
# Processing Record 486 of 607 | neuquen
# Processing Record 487 of 607 | liuli
# Processing Record 488 of 607 | gelibolu
# Processing Record 489 of 607 | axim
# Processing Record 490 of 607 | naples
# Processing Record 491 of 607 | mount darwin
# Processing Record 492 of 607 | maceio
# Processing Record 493 of 607 | tynset
# Processing Record 494 of 607 | abha
# Processing Record 495 of 607 | cuamba
# Processing Record 496 of 607 | belmonte
# Processing Record 497 of 607 | cristinapolis
# Processing Record 498 of 607 | cine
# Processing Record 499 of 607 | palmer
# Processing Record 500 of 607 | natitingou
# City not found. Skipping... gangotri
# Processing Record 501 of 607 | airai
# Processing Record 502 of 607 | daru
# Processing Record 503 of 607 | aswan
# City not found. Skipping... tidore
# Processing Record 504 of 607 | dunedin
# Processing Record 505 of 607 | penzance
# Processing Record 506 of 607 | ivnya
# Processing Record 507 of 607 | aklavik
# Processing Record 508 of 607 | ulagan
# Processing Record 509 of 607 | souillac
# Processing Record 510 of 607 | teguldet
# City not found. Skipping... burica
# Processing Record 511 of 607 | antioquia
# Processing Record 512 of 607 | te anau
# Processing Record 513 of 607 | honiara
# Processing Record 514 of 607 | savannah bight
# Processing Record 515 of 607 | dharmanagar
# Processing Record 516 of 607 | makakilo city
# City not found. Skipping... urumqi
# Processing Record 517 of 607 | ritchie
# Processing Record 518 of 607 | bonavista
# Processing Record 519 of 607 | abu dhabi
# Processing Record 520 of 607 | liverpool
# Processing Record 521 of 607 | hun
# Processing Record 522 of 607 | goure
# Processing Record 523 of 607 | metro
# Processing Record 524 of 607 | amapa
# Processing Record 525 of 607 | tasgaon
# Processing Record 526 of 607 | zheleznodorozhnyy
# Processing Record 527 of 607 | sioux lookout
# Processing Record 528 of 607 | mayumba
# City not found. Skipping... sindand
# Processing Record 529 of 607 | sabaudia
# Processing Record 530 of 607 | plettenberg bay
# City not found. Skipping... eskasem
# City not found. Skipping... nam tha
# Processing Record 531 of 607 | sobolevo
# Processing Record 532 of 607 | kegums
# City not found. Skipping... bardiyah
# Processing Record 533 of 607 | surt
# Processing Record 534 of 607 | luzhou
# Processing Record 535 of 607 | la ligua
# Processing Record 536 of 607 | nishihara
# Processing Record 537 of 607 | phangnga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
summary = ["name","clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
column_names=["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]

cities_df = pd.DataFrame(data,columns=column_names)
cities_df["Date"] = pd.to_datetime(cities_df["Date"],unit='s')
cities_df.head()
# Out:
#            City  Cloudiness Country                Date  Humidity    Lat  \
# 0        Lompoc           1      US 2019-03-19 03:11:50        66  34.64
# 1  Punta Arenas          20      CL 2019-03-19 03:13:05        97 -53.16
# 2      Altamont          90      CA 2019-03-19 03:10:29       100  49.40
# 3      La Ronge          40      CA 2019-03-19 02:00:00        69  55.10
# 4       Paamiut          64      GL 2019-03-19 03:15:58       100  61.99
#
#       Lng  Max Temp  Wind Speed
# 0 -120.46     15.56        1.37
# 1  -70.91      6.00        4.10
# 2  -98.50      1.00        2.72
# 3 -105.30      2.00        1.50
# 4  -49.67     -8.34       10.67

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert Raw Data to DataFrame
# Export the city data into a .csv.
cities_df.to_csv(output_data_file)
# Display the DataFrame
cities_df.count()
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeMaxTemp-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Humidity"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeHumidity-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeCloudiness-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeWindSpeed-Scatter.png", bbox_inches='tight')

# %%
gmaps.configure(api_key=gKey)
# Store latitude and longitude in locations
locations = cities_df[["Lat", "Lng"]].astype(float)
humidity = cities_df["Humidity"].astype(float)
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
#Figure(layout=FigureLayout(height='420px'))
# Out:
# Figure(layout=FigureLayout(height='420px'))
