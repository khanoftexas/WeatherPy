# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from datetime import datetime

# Import API key
from config import (openweathermapy,gKey)
import gmaps

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "metric", "appid": openweathermapy}
summary = ["name","clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
cities_df = pd.DataFrame(["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"])
print("Beginning Data Retrieval")
print("-----------------------------")
counter = 0
weather_data = []
for city in cities:
    try:
        weather_data.append(ow.get_current(city, **settings))
        counter = counter +1
        print(f"Processing Record {counter} of {len(cities)} | {city}")
    except:
        print(f"City not found. Skipping... {city}")
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping... bengkulu
# Processing Record 1 of 619 | bambous virieux
# Processing Record 2 of 619 | punta arenas
# Processing Record 3 of 619 | san quintin
# Processing Record 4 of 619 | atuona
# Processing Record 5 of 619 | hermanus
# Processing Record 6 of 619 | alexandria
# Processing Record 7 of 619 | borskoye
# Processing Record 8 of 619 | tuktoyaktuk
# Processing Record 9 of 619 | srednekolymsk
# Processing Record 10 of 619 | viedma
# Processing Record 11 of 619 | tasiilaq
# Processing Record 12 of 619 | dingle
# Processing Record 13 of 619 | severo-kurilsk
# Processing Record 14 of 619 | torbay
# City not found. Skipping... scottsburgh
# City not found. Skipping... palabuhanratu
# Processing Record 15 of 619 | carnarvon
# Processing Record 16 of 619 | cape town
# Processing Record 17 of 619 | pinar del rio
# Processing Record 18 of 619 | avarua
# Processing Record 19 of 619 | broome
# Processing Record 20 of 619 | ko samui
# City not found. Skipping... illoqqortoormiut
# Processing Record 21 of 619 | vestmannaeyjar
# Processing Record 22 of 619 | rikitea
# Processing Record 23 of 619 | sumenep
# City not found. Skipping... grand river south east
# Processing Record 24 of 619 | kodiak
# Processing Record 25 of 619 | pevek
# Processing Record 26 of 619 | hecun
# Processing Record 27 of 619 | geraldton
# Processing Record 28 of 619 | longyearbyen
# Processing Record 29 of 619 | nasice
# City not found. Skipping... nguiu
# Processing Record 30 of 619 | khatanga
# Processing Record 31 of 619 | kapaa
# City not found. Skipping... pokanayevka
# Processing Record 32 of 619 | verkhoyansk
# Processing Record 33 of 619 | vaini
# Processing Record 34 of 619 | pahalgam
# Processing Record 35 of 619 | mar del plata
# Processing Record 36 of 619 | vrangel
# Processing Record 37 of 619 | kavieng
# City not found. Skipping... viligili
# Processing Record 38 of 619 | hovd
# Processing Record 39 of 619 | mareeba
# Processing Record 40 of 619 | souillac
# City not found. Skipping... tsihombe
# Processing Record 41 of 619 | brejo da madre de deus
# City not found. Skipping... barentsburg
# Processing Record 42 of 619 | saldanha
# City not found. Skipping... arrecife
# Processing Record 43 of 619 | bethanien
# Processing Record 44 of 619 | iwaki
# Processing Record 45 of 619 | zhangye
# Processing Record 46 of 619 | marsh harbour
# Processing Record 47 of 619 | hillsborough
# Processing Record 48 of 619 | ushuaia
# Processing Record 49 of 619 | lebu
# Processing Record 50 of 619 | kavaratti
# Processing Record 51 of 619 | singaraja
# Processing Record 52 of 619 | port alfred
# Processing Record 53 of 619 | upernavik
# Processing Record 503 of 619 | sawtell
# Processing Record 504 of 619 | henderson
# Processing Record 505 of 619 | honggang
# City not found. Skipping... stoyba
# Processing Record 506 of 619 | pangnirtung
# Processing Record 507 of 619 | abonnema
# Processing Record 508 of 619 | husavik
# Processing Record 509 of 619 | mahebourg
# Processing Record 510 of 619 | kupang
# Processing Record 511 of 619 | kozhva
# Processing Record 512 of 619 | hami
# Processing Record 513 of 619 | noumea
# City not found. Skipping... tokzar
# Processing Record 514 of 619 | guerrero negro
# Processing Record 515 of 619 | southbridge
# Processing Record 516 of 619 | tilichiki
# Processing Record 517 of 619 | springdale
# Processing Record 518 of 619 | moussoro
# City not found. Skipping... koungou
# Processing Record 519 of 619 | zyryanka
# Processing Record 520 of 619 | singaparna
# Processing Record 521 of 619 | solntsevo
# Processing Record 522 of 619 | erzin
# Processing Record 523 of 619 | pilar
# Processing Record 524 of 619 | heihe
# Processing Record 525 of 619 | borovoy
# Processing Record 526 of 619 | pandan
# Processing Record 527 of 619 | pozo colorado
# City not found. Skipping... ndele
# Processing Record 528 of 619 | dongling
# Processing Record 529 of 619 | wadi maliz
# Processing Record 530 of 619 | beira
# Processing Record 531 of 619 | tolyatti
# Processing Record 532 of 619 | baykit
# Processing Record 533 of 619 | gat
# Processing Record 534 of 619 | madaoua
# Processing Record 535 of 619 | sorsk
# Processing Record 536 of 619 | maputo
# Processing Record 537 of 619 | nouadhibou
# Processing Record 538 of 619 | kentau
# Processing Record 539 of 619 | waingapu
# Processing Record 540 of 619 | yerbogachen
# Processing Record 541 of 619 | birjand
# Processing Record 542 of 619 | galle
# Processing Record 543 of 619 | quang ngai
# Processing Record 544 of 619 | port-gentil
# Processing Record 545 of 619 | locri
# City not found. Skipping... achisay
# Processing Record 546 of 619 | iralaya
# Processing Record 547 of 619 | estreito
# Processing Record 548 of 619 | port keats
# Processing Record 549 of 619 | oranjemund
# City not found. Skipping... kismayo
# Processing Record 550 of 619 | sanjwal
# Processing Record 551 of 619 | ponta delgada
# Processing Record 552 of 619 | naryan-mar
# Processing Record 553 of 619 | estevan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
summary = ["name","clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
column_names=["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]

cities_df = pd.DataFrame(data,columns=column_names)
cities_df["Date"] = pd.to_datetime(cities_df["Date"],unit='s')
cities_df.head()
# Out:
#               City  Cloudiness Country                Date  Humidity    Lat  \
# 0  Bambous Virieux          75      MU 2019-03-19 03:54:03        83 -20.34
# 1     Punta Arenas          75      CL 2019-03-19 03:53:17        75 -53.16
# 2      San Quintin           0      PH 2019-03-19 03:56:29        57  17.54
# 3           Atuona          56      PF 2019-03-19 03:49:59        98  -9.80
# 4         Hermanus          64      ZA 2019-03-19 03:46:59        95 -34.42
#
#       Lng  Max Temp  Wind Speed
# 0   57.76     27.00        4.10
# 1  -70.91      5.00        4.10
# 2  120.52     29.71        1.17
# 3 -139.03     28.41        6.57
# 4   19.24     17.78        1.37

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert Raw Data to DataFrame
# Export the city data into a .csv.
cities_df.to_csv(output_data_file)
# Display the DataFrame
cities_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeMaxTemp-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Humidity"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeHumidity-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeCloudiness-Scatter.png", bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], color="RoyalBlue", edgecolor = 'black',alpha=.75,linewidths=1.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({datetime.now().strftime('%m/%d/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save Figure
plt.savefig("Images/LatitudeWindSpeed-Scatter.png", bbox_inches='tight')

# %%
# gmaps.configure(api_key=gKey)
# # Store latitude and longitude in locations
# locations = cities_df[["Lat", "Lng"]].astype(float)
# humidity = cities_df["Humidity"].astype(float)
# # Plot Heatmap
# fig = gmaps.figure()

# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=1)


# # Add layer
# fig.add_layer(heat_layer)

# # Display figure
# fig =gmaps.figure(layout={
#         'width': '280px',
#         'height': '420px',
#         'padding': '3px',
#         'border': '1px solid black'
# })
